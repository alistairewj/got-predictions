# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import sys
from sklearn.cross_validation import cross_val_predict

from sklearn.pipeline import Pipeline

# used for train/test splits and cross validation
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV

# used to impute mean for data and standardize for computational stability
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler

# logistic regression is our favourite model ever
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LassoCV

# used to calculate AUROC/accuracy
from sklearn import metrics

# used to create confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.cross_validation import cross_val_score

# gradient boosting - must download package https://github.com/dmlc/xgboost
#import xgboost as xgb

# default colours for prettier plots

col = [[0.9047, 0.1918, 0.1988],
    [0.2941, 0.5447, 0.7494],
    [0.3718, 0.7176, 0.3612],
    [1.0000, 0.5482, 0.1000],
    [0.4550, 0.4946, 0.4722],
    [0.6859, 0.4035, 0.2412],
    [0.9718, 0.5553, 0.7741],
    [0.5313, 0.3359, 0.6523]];
marker = ['v','o','d','^','s','o','+']
ls = ['-','-','-','-','-','s','--','--']
# %matplotlib inline

from __future__ import print_function

# %%
# read data from the got-data.ipynb file
# most of it is scrapped from the game of thrones tv show wiki
df = pd.read_csv('data/got_data_all_characters.csv', sep=',', index_col=0)

# who do we not have data for?
idxRemove = (df['Season(s)'].isnull())
print('Never appeared... ({} characters)'.format(np.sum(idxRemove)))
#print(df[idxRemove].index)
# delete people with no data - they have no scores and never appeared in any season
df = df.loc[~idxRemove]


# remove video game characters
idxRemove = [i for i, s in enumerate(df['Season(s)']) if 'A Telltale Games Series' in s]
print('\nVideo games... ({} characters)'.format(len(idxRemove)))
#print(df.iloc[idxRemove].index)
df = df.iloc[ [i for i in range(df.shape[0]) if i not in idxRemove]  ]


# pick all who died but weren't in a season
idxRemove = (df['Status'].values == 'Deceased') & (df['Season(s)'].isnull())
df = df.loc[~idxRemove]
print('\nDeleting {} who died and were never in the show.'.format(np.sum(idxRemove)))

# pick all who survived past season 1 - this filters a lot of background characters
idxRemove = (df['Status'].values == 'Deceased') & (df['Season(s)'].values == '1')
df = df.loc[~idxRemove]
print('\nRemoved {} who died on/before season 1. Ned :('.format(np.sum(idxRemove)))

# remove all who appeared/died in the same season
for s in ['1','2','3','4','5','6']:
    idxRemove = (df['Season(s)'].values == s) | (str(df['Season(s)'].values) == s)
    df = df.loc[~idxRemove]
    print('Removed {} characters who '.format(np.sum(idxRemove)) + \
          'only appeared in season {}.'.format(s))

# remove the bloody random targaryens
p = re.compile('_Targaryen')
idxRemove = [s for s in df.index if p.search(s) is not None and 'Daenerys' not in s]
print('\nRemoved {} bloody Targaryens.'.format(len(idxRemove)))
df.drop(idxRemove,axis=0,inplace=True)

# remove historical characters
idxRemove = [s for s in df.index
             if df.loc[s,'Season(s)'] == 'Histories & Lore' or
             df.loc[s,'Season(s)'] == 'Complete Guide to Westeros, Histories & Lore']
print('\nRemoved {} historical characters.'.format(len(idxRemove)))
df.drop(idxRemove,axis=0,inplace=True)

# print out the data we have
print('\nTotal of {} characters.'.format(df.shape[0]))
# Out:
# Never appeared... (18 characters)
#
# Video games... (72 characters)
#
# Deleting 0 who died and were never in the show.
#
# Removed 88 who died on/before season 1. Ned :(
# Removed 87 characters who only appeared in season 1.
# Removed 93 characters who only appeared in season 2.
# Removed 76 characters who only appeared in season 3.
# Removed 101 characters who only appeared in season 4.
# Removed 88 characters who only appeared in season 5.
# Removed 26 characters who only appeared in season 6.
#
# Removed 12 bloody Targaryens.
#
# Removed 58 historical characters.
#
# Total of 185 characters.

# %%
for i in df.index:
    if df.loc[i,'Status'] is np.nan:
        print('{:50s} - nan'.format(i))
    elif ('Dead' in df.loc[i, 'Status']) | ('Deceased' in df.loc[i, 'Status']):
        s = df.loc[i,'Season(s)']
        s = s[-1]
        print('{:50s} - died in season {} (was in {})'.format(i, s, df.loc[i,'Season(s)']))
    else:
        print('{:50s} - alive (was in {})'.format(i, df.loc[i,'Season(s)']))
# Out:
# Aemon                                              - died in season 5 (was in 1, 3, 4, 5)
# Alliser_Thorne                                     - alive (was in 1, 4, 5, 6)
# Areo_Hotah                                         - died in season 6 (was in 5, 6)
# Armeca                                             - alive (was in 1, 2)
# Arwaya_Frey                                        - alive (was in 1, 3)
# Arya_Stark                                         - alive (was in 1, 2, 3, 4, 5, 6)
# Arys_Oakheart                                      - alive (was in 1, 2,  5)
# Balon_Greyjoy                                      - alive (was in 2, 3, 6)
# Balon_Swann                                        - alive (was in 2, 3,  5)
# Barra                                              - died in season 2 (was in 1, 2)
# Barristan_Selmy                                    - died in season 5 (was in 1, 3, 4, 5)
# Benjen_Stark                                       - alive (was in 1, 6)
# Beric_Dondarrion                                   - alive (was in 1, 3)
# Biter                                              - died in season 4 (was in 1, 2, 4)
# Boros_Blount                                       - alive (was in 1, 2, 3, 4, 5)
# Bowen_Marsh                                        - alive (was in 5, 6)
# Bran_Stark                                         - alive (was in 1, 2, 3, 4, 6)
# Brandon_Stark_(Son_of_Rickard)                     - died in season 5 (was in 1, 4, 5)
# Brandon_Stark_(the_Builder)                        - died in season 5 (was in 1, 5)
# Brienne_of_Tarth                                   - alive (was in 2, 3, 4, 5, 6)
# Bronn                                              - alive (was in 1, 2, 3, 4, 5, 6)
# Brynden_Tully                                      - alive (was in 3, 6)
# Catelyn_Stark                                      - died in season 3 (was in 1, 2, 3)
# Cersei_Lannister                                   - alive (was in 1, 2, 3, 4, 5, 6)
# Chella                                             - alive (was in 1, 2)
# Craster                                            - died in season 3 (was in 2, 3)
# Daario_Naharis                                     - alive (was in 3, 4, 5, 6)
# Daenerys_Targaryen                                 - alive (was in 1, 2, 3, 4, 5, 6)
# Davos_Seaworth                                     - alive (was in 2, 3, 4, 5, 6)
# Dongo                                              - died in season 4 (was in 3, 4)
# Dontos_Hollard                                     - died in season 4 (was in 2, 4)
# Doran_Martell                                      - alive (was in 5, 6)
# Doreah                                             - died in season 2 (was in 1, 2)
# Drogo                                              - died in season 2 (was in 1, 2)
# Drogon                                             - alive (was in 1, 2, 3, 4, 5)
# Duncan_the_Tall                                    - died in season 4 (was in 1, 4)
# Dwarf_1                                            - died in season 5 (was in 4, 5)
# Eddard_Stark                                       - died in season 6 (was in 1, 6)
# Eddison_Tollett                                    - alive (was in 2, 3, 4, 5, 6)
# Edmure_Tully                                       - alive (was in 3, 6)
# Edric_Baratheon                                    - died in season 3 (was in Season 3)
# Elia_Martell                                       - died in season 5 (was in Complete Guide to Westeros, 4, 5)
# Ellaria_Sand                                       - alive (was in 4, 5, 6)
# Garlan_Tyrell                                      - alive (was in HBO Viewer's Guide)
# Gendry                                             - alive (was in 1, 2, 3)
# Ghost                                              - alive (was in 1, 2, 3, 4, 5, 6)
# Gilly                                              - alive (was in 2, 3, 4, 5, 6)
# Gregor_Clegane                                     - alive (was in 1, 2, 4, 5, 6)
# Grenn                                              - died in season 4 (was in 1, 2, 3, 4)
# Grey_Wind                                          - died in season 3 (was in 1, 2, 3)
# Grey_Worm                                          - alive (was in 3, 4, 5, 6)
# Harrion_Karstark                                   - died in season 3 (was in 2, 3)
# High_Septon_(After_the_riot_of_King%27s_Landing)   - alive (was in 3, 4, 5)
# High_Septon_(Before_the_riot_of_King%27s_Landing)  - died in season 2 (was in 1, 2)
# High_Sparrow                                       - alive (was in 5, 6)
# Hizdahr_zo_Loraq                                   - died in season 5 (was in 4, 5)
# Hodor                                              - alive (was in 1, 2, 3, 4, 6)
# Hot_Pie                                            - alive (was in 1, 2, 3, 4)
# Ilyn_Payne                                         - alive (was in 1, 2)
# Irri                                               - died in season 2 (was in 1, 2)
# Jacks                                              - alive (was in 1, 2)
# Jaime_Lannister                                    - alive (was in 1, 2, 3, 4, 5, 6)
# Janos_Slynt                                        - died in season 5 (was in 1, 2, 4, 5)
# Jaqen_H%27ghar                                     - alive (was in 1, 2, 5, 6)
# Jeor_Mormont                                       - died in season 3 (was in 1, 2, 3)
# Joanna_Lannister                                   - died in season 5 (was in 2, 3, 5)
# Joffrey_Baratheon                                  - died in season 4 (was in 1, 2, 3, 4)
# Jojen_Reed                                         - died in season 4 (was in 3, 4)
# Jorah_Mormont                                      - alive (was in 1, 2, 3, 4, 5, 6)
# Joss_Stilwood                                      - alive (was in 1, 4)
# Joyeuse_Erenford                                   - died in season 3 (was in 1, 3)
# Karl_Tanner                                        - died in season 4 (was in 3, 4)
# Kayla                                              - alive (was in 3, 4)
# Kevan_Lannister                                    - alive (was in 1, 2, 5, 6)
# Lancel                                             - alive (was in 1, 2, 5, 6)
# Lannister_bannerman_1_(The_Ghost_of_Harrenhal)     - alive (was in 2 4)
# Lannister_bannerman_2_(The_Ghost_of_Harrenhal)     - alive (was in 1, 2, 3)
# Lannister_bannerman_3_(The_Ghost_of_Harrenhal)     - alive (was in 2, 3)
# Lhara                                              - alive (was in 4, 5)
# Locke                                              - died in season 4 (was in 3, 4)
# Lommy                                              - died in season 2 (was in 1, 2)
# Loras_Tyrell                                       - alive (was in 1, 2, 3, 4, 5, 6)
# Lord_of_Bones                                      - died in season 5 (was in 2, 3, 5)
# Lothar_Frey                                        - alive (was in 3, 6)
# Luwin                                              - died in season 2 (was in 1, 2)
# Lysa_Arryn                                         - died in season 4 (was in 1, 4)
# Mace_Tyrell                                        - alive (was in 4, 5, 6)
# Mance_Rayder                                       - died in season 5 (was in 3, 4, 5)
# Mandon_Moore                                       - died in season 2 (was in 1, 2)
# Marei                                              - alive (was in 2, 3, 4, 5, 6)
# Margaery_Tyrell                                    - alive (was in 2, 3, 4, 5, 6)
# Maron_Greyjoy                                      - died in season 2 (was in 1, 2)
# Marya_Seaworth                                     - alive (was in 2, 3)
# Meera_Reed                                         - alive (was in 3, 4, 6)
# Melisandre                                         - alive (was in 2, 3, 4, 5, 6)
# Meryn_Trant                                        - died in season 5 (was in 1, 2, 3, 4, 5)
# Mhaegen                                            - alive (was in 1, 2)
# Missandei                                          - alive (was in 3, 4, 5, 6)
# Mossador                                           - died in season 5 (was in 4, 5)
# Myranda                                            - died in season 6 (was in 3, 4, 5, 6)
# Myrcella_Baratheon                                 - died in season 6 (was in 1, 2, 5, 6)
# Night%27s_King                                     - alive (was in 4, 5, 6)
# Night%27s_Watch_Officer_2                          - alive (was in 1, 2, 3, 4, 5)
# Nymeria_Sand                                       - alive (was in 5, 6)
# Obara_Sand                                         - alive (was in 5, 6)
# Olenna_Tyrell                                      - alive (was in 3, 4, 5, 6)
# Olly                                               - alive (was in 4, 5, 6)
# Olyvar                                             - alive (was in 3, 4, 5)
# Osha                                               - alive (was in 1, 2, 3, 6)
# Othell_Yarwyck                                     - alive (was in 1, 4, 5, 6)
# Petyr_Baelish                                      - alive (was in 1, 2, 3, 4, 5, 6)
# Petyr_Baratheon                                    - died in season 3 (was in Season 3)
# Podrick_Payne                                      - alive (was in 2, 3, 4, 5, 6)
# Polliver                                           - died in season 4 (was in 2, 4)
# Preston_Greenfield                                 - alive (was in 1, 2, 3, 4, 5, 6)
# Pycelle                                            - alive (was in 1, 2, 3, 4, 5, 6)
# Pypar                                              - died in season 4 (was in 1, 3, 4)
# Qyburn                                             - alive (was in 3, 4, 5, 6)
# Rakharo                                            - died in season 2 (was in 1, 2)
# Ramsay_Bolton                                      - alive (was in 3, 4, 5, 6)
# Rast                                               - died in season 4 (was in 1, 3, 4)
# Razdal_mo_Eraz                                     - alive (was in 3, 6)
# Renly_Baratheon                                    - died in season 2 (was in 1, 2)
# Rhaegal                                            - alive (was in 1, 2, 3, 4, 5)
# Rhaego                                             - died in season 2 (was in 1, 2)
# Rickard_Karstark                                   - died in season 3 (was in 1, 2, 3)
# Rickard_Stark                                      - died in season 5 (was in 1, 5)
# Rickon_Stark                                       - alive (was in 1, 2, 3, 6)
# Robb_Stark                                         - died in season 3 (was in 1, 2, 3)
# Robin_Arryn                                        - alive (was in 1, 4, 5, 6)
# Rodrik_Cassel                                      - died in season 2 (was in 1, 2)
# Rodrik_Greyjoy                                     - died in season 2 (was in 1, 2)
# Roose_Bolton                                       - alive (was in 2, 3, 4, 5, 6)
# Rorge                                              - died in season 4 (was in 1, 2, 4)
# Ros                                                - died in season 3 (was in 1, 2, 3)
# Salladhor_Saan                                     - alive (was in 2, 3, 4)
# Sam                                                - alive (was in 3, 4, 5, 6)
# Samwell_Tarly                                      - alive (was in 1, 2, 3, 4, 5, 6)
# Sandor_Clegane                                     - alive (was in 1, 2, 3, 4)
# Sansa_Stark                                        - alive (was in 1, 2, 3, 4, 5, 6)
# Scolera                                            - alive (was in  5)
# Selwyn_Tarth                                       - alive (was in 2, 3, 4, 5)
# Selyse_Baratheon                                   - died in season 5 (was in 2, 3, 4, 5)
# Shae                                               - died in season 6 (was in 1, 2, 3, 4, 6)
# Shaggydog                                          - alive (was in 1, 2, 3)
# Shireen_Baratheon                                  - died in season 5 (was in 3, 4, 5)
# Stannis_Baratheon                                  - died in season 5 (was in 2, 3, 4, 5)
# Steffon_Baratheon                                  - died in season 5 (was in 1, 5)
# Talisa_Stark                                       - died in season 3 (was in 2, 3)
# Ternesio_Terys                                     - alive (was in 4, 5)
# Theon_Greyjoy                                      - alive (was in 1, 2, 3, 4, 5, 6)
# Thoros                                             - alive (was in 3, 6)
# Three-eyed_raven                                   - alive (was in 1, 3, 4, 6)
# Timett                                             - alive (was in 1, 2)
# Tobho_Mott                                         - alive (was in 1, 2)
# Todder                                             - alive (was in 1, 3, 5)
# Tommard_Baratheon                                  - died in season 3 (was in Season 3)
# Tommen_Baratheon                                   - alive (was in 1, 2, 4, 5, 6)
# Tormund                                            - alive (was in 3, 4, 5, 6)
# Trystane_Martell                                   - alive (was in 5, 6)
# Tycho_Nestoris                                     - alive (was in 4, 5)
# Tyene_Sand                                         - alive (was in 5, 6)
# Tyrion_Lannister                                   - alive (was in 1, 2, 3, 4, 5, 6)
# Tysha                                              - alive (was in 1, 2, 3)
# Tytos_Lannister                                    - died in season 2 (was in 1, 2)
# Tywin_Lannister                                    - died in season 5 (was in 1, 2, 3, 4, 5)
# Unella                                             - alive (was in 5, 6)
# Unidentified_handmaiden                            - alive (was in 2, 3, 4, 6)
# Varys                                              - alive (was in 1, 2, 3, 4, 5, 6)
# Viserion                                           - alive (was in 1, 2, 3, 4, 5)
# Waif                                               - alive (was in 5, 6)
# Walda_Bolton                                       - alive (was in 4, 5, 6)
# Walder_Frey                                        - alive (was in 1, 3, 6)
# Walder_Rivers                                      - alive (was in 3, 6)
# White_Walker_(Oathkeeper)                          - alive (was in 4,5)
# White_Walker_(Valar_Morghulis)                     - died in season 3 (was in 2, 3)
# Willas_Tyrell                                      - alive (was in HBO Viewer's Guide)
# Willem_Frey                                        - alive (was in 2, 3)
# Wolkan                                             - alive (was in 5, 6)
# Wun_Weg_Wun_Dar_Wun                                - alive (was in 5, 6)
# Yara_Greyjoy                                       - alive (was in 2, 3, 4, 6)
# Yezzan_zo_Qaggaz                                   - alive (was in 5, 6)
# Ygritte                                            - died in season 4 (was in 2, 3, 4)
# Yohn_Royce                                         - alive (was in 4, 5, 6)
# Yoren                                              - died in season 2 (was in 1, 2)

# %%
# write data to file
df.to_csv('data/got_data_valid_characters.csv')
