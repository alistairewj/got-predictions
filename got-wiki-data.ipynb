# %%
from __future__ import print_function
from bs4 import BeautifulSoup
import urllib
import nltk
import re
from pprint import pprint
import csv
from collections import OrderedDict
import pandas as pd
import numpy as np
import unicodedata
import got_utils as gu

# %%
# load in character list
character_list = []
char_list = open('data/all_characters.txt', 'r')
for char in char_list:  
    character_list.append(char.replace('\n',''))
    
char_list.close()

# %%
reload(gu)
# this code block is useful for testing if it worked on an individual character
char = 'Tyrell_bannerman'
char = char.replace('\n','') # remove newline sometimes contained in character name


# initialize some vars
c = {'Season 1': {},
    'Season 2': {},
    'Season 3': {},
    'Season 4': {},
    'Season 5': {},
    'Background': {}}
key_words = ["Season(s)", "First seen", "Last seen", "Appeared in", "Mentioned in", "Titles", "Also known as", "Status",
             "Age", "Date of birth", "Death", "Origin", "Allegiance", "Culture", "Religion", "Family", "Portrayed by"]
char_info = {}
# initialize dicionary with key words
for key in key_words:
    char_info[key] = {}
char_info['Name'] = {} # since we handle name separately, we decide not to include it in the key_words list

# get the data from the wiki page
url = 'http://gameofthrones.wikia.com/wiki/' + char
page = urllib.urlopen(url)
soup = BeautifulSoup(page.read(), "html.parser")


# Output structured info from the right side of the wiki page
print('Name: {}'.format(char.replace('_',' ')))

for word in key_words:
    keys = soup.find(text=word)
    if keys is not None:
        value = keys.parent.findNextSibling('div')
        if value is not None:
            if word == 'Family':
                # specially process family
                
            else:
                char_info[word][char] = value.text
                
            print('{}: {}'.format(word, unicodedata.normalize('NFKD', value.text).encode('ascii','ignore')))
        #TODO: special case for family, create a dictionary


# call function to get text data
char_c = gu.return_character_dictionary(soup, char, c)

for item in char_c:
    if char_c[item] is not None:
        print('{} text: found!'.format(item))
    else:
        print('{} text: absent!'.format(item))
# Out:
# Name: Arya Stark
# Season(s): 1, 2, 3, 4, 5, 6
# First seen: "Winter is Coming"
# Appeared in: 40 episodes (see below)
# Titles: Princess
# Also known as: ArryLanna
# Status: Alive
# Age: 11 in season 1 and 16 in season 6
# Origin: Winterfell
# Allegiance: House StarkFaceless Men
# Culture: Northmen
# Religion: Old Gods of the Forest (formerly)Faith of the Seven (formerly)Many-Faced God
# Family: {Eddard Stark} - father{Catelyn Stark} - mother{Robb Stark} - brotherSansa Stark - sisterBran Stark - brotherRickon Stark - brother{Jon Snow} - bastard paternal half-brotherBenjen Stark - paternal uncle{Brandon Stark} - paternal uncle{Lyanna Stark} - paternal aunt{Jon Arryn} - uncle by marriagePetyr Baelish - uncle by marriageRoslin Frey - aunt by marriage{Rickard Stark} -  paternal grandfatherBrynden Tully - maternal great-uncle{Hoster Tully} - maternal grandfather{Minisa Tully} - maternal grandmotherEdmure Tully - maternal uncle{Lysa Arryn} - maternal auntRobin Arryn - maternal first cousin{Talisa Maegyr} - sister-in-lawTyrion Lannister - brother-in-lawRamsay Bolton - brother-in-law
# Portrayed by: Maisie Williams
# Background text: found!
# Season 5 text: found!
# Season 4 text: found!
# Season 3 text: found!
# Season 2 text: found!
# Season 1 text: found!

# %% [markdown]
# ```
# word = 'Family'
# keys = soup.find(text=word)
# value = keys.parent.findNextSibling('div')
# print(value.text)
#
# fam = value.findNext('a')
#
# print(fam.text)
# print(value.findNext('br'))
# ```

# %%
# now using the above function, create a dictionary with all our characters and their text data
c = {'Season 1': {},
    'Season 2': {},
    'Season 3': {},
    'Season 4': {},
    'Season 5': {},
    'Background': {}}

# at the same time get other structured info
key_words = ["Season(s)", "First seen", "Last seen", "Appeared in", "Mentioned in", "Titles", "Also known as", "Status",
             "Age", "Date of birth", "Death", "Origin", "Allegiance", "Culture", "Religion", "Family", "Portrayed by"]

info = {}
# initialize dicionary with key words
for key in key_words:
    info[key] = {}
info['Name'] = {} # since we handle name separately, we decide not to include it in the key_words list
count_char = 1

for char in character_list:
    char = char.replace('\n','') # remove newline sometimes contained in character name
    
    if np.mod( character_list.index(char), 5 ) == 0:
        print('') #newline, i.e. only print 5 character names per line
    print ('{} .. '.format(char), end="")
        
    # get the data from the wiki page
    url = 'http://gameofthrones.wikia.com/wiki/' + char
    page = urllib.urlopen(url)
    soup = BeautifulSoup(page.read(), "html.parser")
    
    # Output structured info from the right side of the wiki page
    info['Name'][char] = char.replace('_',' ')

    for word in key_words:
        keys = soup.find(text=word)
        if keys is not None:
            value = keys.parent.findNextSibling('div')
            if value is not None:
                info[word][char] = value.text

            #TODO: special case for family, create a dictionary
    
    
    # call function to get text data
    c = gu.return_character_dictionary(soup, char, c)
# Out:
# Aemon .. Aemond_Targaryen .. Aggar .. Aggo .. Ahko ..
# Allo .. Amaya .. Anara .. Andros .. Anguy ..
# Armeca .. Alys_Arryn .. Artys_Arryn .. Jasper_Arryn .. Jon_Arryn ..
# Lysa_Arryn .. Robin_Arryn .. Ronnel_Arryn .. Ronnel_Arryn_(King) .. Sharra_Arryn ..
# Arson_Iceaxe .. Arthur_Glenmore .. Arwaya_Frey .. Ashford_(Lord) .. Aya ..
# Azor_Ahai .. Baelish_(father_of_Petyr) .. Baelish_(founder) .. Baelish_(hedge_knight) .. Petyr_Baelish ..
# Balian .. Bannen .. Joffrey_Baratheon .. Baratheon_General .. Baratheon_officer ..
# Baratheon_soldier .. Argalia_Baratheon .. Axel_Baratheon .. Cassana_Baratheon .. Edric_Baratheon ..
# Lyonel_Baratheon .. Monica_Baratheon .. Mychal_Baratheon .. Myrcella_Baratheon .. Orys_Baratheon ..
# Petyr_Baratheon .. Renly_Baratheon .. Robert_Baratheon .. Selyse_Baratheon .. Shireen_Baratheon ..
# Stannis_Baratheon .. Steffon_Baratheon .. Tommard_Baratheon .. Tommen_Baratheon .. Barra ..
# Bathhouse_prostitute .. Humfrey_Beesbury .. Lyman_Beesbury .. Beggar_woman .. Bert ..
# Bessie .. Bezzaq .. Bharbo .. Billy .. Biter ..
# Daemon_Blackfyre .. Aemon_Blackfyre .. Daemon_II_Blackfyre .. Serena_Blackfyre .. Blackmont_(Lord) ..
# Bloodsong .. Boros_Blount .. Boake .. Boat_commander .. Bobono ..
# Roose_Bolton .. Bolton_man_1 .. Bolton_man_2 .. Bolton_soldier_(Walk_of_Punishment) .. Domeric_Bolton ..
# Ramsay_Bolton .. Rogar_Bolton .. Walda_Bolton .. Borba .. Borcas ..
# Minisa_Tully .. Duncan_Tuttle .. Gared_Tuttle .. Tyrell_bannerman .. Tyrell_lady ..
# Tyrell_servant .. Alerie_Tyrell .. Allana_Tyrell .. Garlan_Tyrell .. Harlen_Tyrell ..
# Loras_Tyrell .. Luthor_Tyrell .. Lyonel_Tyrell .. Mace_Tyrell .. Margaery_Tyrell ..
# Olenna_Tyrell .. Willas_Tyrell .. Tysha .. Ulf .. Greizhen_mo_Ullhor ..
# Amarylis_Umber .. Corin_Umber .. Harkon_Umber .. Hothor_Umber .. Jon_Umber ..
# Lucan_Umber .. Morag_Umber .. Mycah_Umber .. Jon_Umber_(Smalljon) .. Unella ..
# Unidentified_handmaiden .. Unidentified_Warlock .. Unsullied_1_(Oathkeeper) .. Unsullied_1_(Valar_Dohaeris) .. Urzen ..
# Valyrian_slave .. Valyrian_sword_smith .. Varly .. Varys .. Vaull ..
# Vermithrax .. Violet .. Viserion .. Volarik .. Vorkoy ..
# Waif .. Wallen .. Walter_Whent .. Marston_Waters .. Anya_Waynwood ..
# Weasel .. Wendel .. Wex .. Oswell_Whent .. Shella_Whent ..
# White_Rat .. White_Walker_(Hardhome) .. White_Walker_(Oathkeeper) .. White_Walker_(The_Night_Lands) .. White_Walker_(Valar_Morghulis) ..
# White_Walker_(Winter_is_Coming) .. Whitehill_soldier_1 .. Gryff_Whitehill .. Gwyn_Whitehill .. Ludd_Whitehill ..
# Whore_(Mother_of_Dragons) .. Whore_(The_Crone) .. Whore_(The_Maiden) .. Whore_(The_Mother) .. Whore_(The_Smith) ..
# Whore_(The_Stranger) .. Whore_(The_Warrior) .. Whore_(Two_Swords) .. Wibberley_(Lord) .. Wildling_elder ..
# Wildling_female .. Wildling_girl .. Will .. Willem .. Willem_Wylde ..
# Wineseller .. Winterfell_shepherd .. Winterfell_worker .. Willis_Wode .. Wolkan ..
# Wounded_Lannister .. Wun_Weg_Wun_Dar_Wun .. Wyl_(House_Stark) .. Wylla .. Xaro_Xhoan_Daxos ..
# Othell_Yarwyck .. Ygritte .. Yoren .. Young_Bravo .. Edgar_Yronwood ..
# Yunkai%27i_slave_1 .. Yunkai%27i_slave_2 .. Yunkai%27i_slave_3 .. Yunkai%27i_slave_4 .. Yunkai%27i_slave_5 ..
# Yunkai%27i_slave_6 .. Yunkai%27i_whore .. Zalla .. Zanrush ..

# %%
# create data frames of the above
df_info_unicode = pd.DataFrame.from_dict(info)
df_txt_unicode = pd.DataFrame.from_dict(c, dtype='unicode')

# %%
# convert the unicode dataframe to ascii text - as best we can, this will inevitably remove/alter some characters
def convert_text(s):
    if str(type(s)) == "<type 'unicode'>":
        txt = unicodedata.normalize('NFKD', s).encode('ascii','ignore')
        return txt.replace("\\'", "'")  # remove escape characters
    else:
        return None

d = {}
for col in df_info_unicode.columns:
    d[col] = df_info_unicode[col].apply(convert_text)

df_info = pd.DataFrame(d)

d = {}
for col in df_txt_unicode.columns:
    d[col] = df_txt_unicode[col].apply(convert_text)

df_txt = pd.DataFrame(d)

# %%
# write data to file
df = df_info.merge(df_txt, left_index=True, right_index=True, how='left')
df.to_csv('data/got_data_all_characters.csv')
